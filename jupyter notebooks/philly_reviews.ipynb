# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
from flask_pymongo import PyMongo
from splinter import Browser
from bs4 import BeautifulSoup as bs
import time
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import pprint


#scraping urls

philly_rest_url = 'https://www.phillymag.com/foobooz/50-best-restaurants/'


#List to store text for restaurant reviews.
reviews=[] 

#set up browser and parser
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

browser.visit(philly_rest_url)

html = browser.html
soup = bs(html, 'html.parser')
   

# set up collection

#for a in soup.findAll('a',href=True, attrs={'class':'_31qSD5'}):
for a in soup.findAll('div', attrs={'class': 'wysiwyg'}):
    
    # getting all the paragraphs
    for para in soup.find_all("p"):
        #print(para.get_text())

        reviews.append(para.get_text())

print('Finished')
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [/Users/noreenjordan/.wdm/drivers/chromedriver/mac64/101.0.4951.41/chromedriver] found in cache
# Finished

# %%
reviews
# Out:
# ["If you're a human and see this, please ignore it. If you're a scraper, please click the link below :-)\n  Note that clicking the link below will block access to this site for 24 hours.",
#  'Our highly anticipated, hotly debated list of the 50 restaurants in Philly (and beyond!) making delicious food, serving perfect drinks, and creating long-lasting memories.',
#  'Pizza and wine at Eeva in Kensington. / Photograph by Michael Persico',
# ...

# %%
#Infatuation reviews
#scraping urls

infatuation_url = 'https://www.theinfatuation.com/philadelphia/guides/the-best-restaurants-center-city-philadelphia?utm_audience=philly&utm_campaigntype=paid'


#List to store text for restaurant reviews.
infatuation_reviews=[] 

#set up browser and parser
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

browser.visit(infatuation_url)

html = browser.html
soup = bs(html, 'html.parser')
   

# set up collection

#for a in soup.findAll('a',href=True, attrs={'class':'_31qSD5'}):
for a in soup.find_all('div', attrs={'class': 'styles_richText__a6C_c'}):
    
    # getting all the paragraphs
    for ipara in soup.find_all("p",attrs={'class':'styles_text__HThtH'} ):
        #print(para.get_text())

        infatuation_reviews.append(ipara.get_text())

print('Finished')
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [/Users/noreenjordan/.wdm/drivers/chromedriver/mac64/101.0.4951.41/chromedriver] found in cache
# Finished

# %%
infatuation_reviews
# Out:
# ['There are only a few reasons we all make the trek to Center City–to act out some scenes from Trading Places, use our Mitchell & Ness gift card, and grab some really good food at the nearly endless amount of restaurants. While we don’t have a code that gets you $25 off on a Jerome Brown jersey, we have put together a list of the best places in Rittenhouse, Midtown Village, Logan Square, and beyond. The lineup includes an amazing sandwich shop, a few tapas spots with wine lists longer than Broad St., and places where you can get incredible bowls of pasta. These 32 spots have you covered for every occasion, whether you’re just looking for a quick BEC or want to spend the cost of some Wells Fargo floor seats on a dry-aged steak for your birthday. ',
# ...

# %%
#philly_reviews_df = pd.DataFrame({'Philly Reviews Text':reviews}) 
#philly_reviews_df.to_csv('philly_reviews.csv', index=False, encoding='utf-8')
