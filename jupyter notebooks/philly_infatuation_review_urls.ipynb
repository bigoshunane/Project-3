# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
from flask_pymongo import PyMongo
from splinter import Browser
from bs4 import BeautifulSoup as bs
import time
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import pprint

# %%
url = 'https://www.theinfatuation.com/philadelphia/reviews'

# %%
#scraping urls

infatuation_url = 'https://www.theinfatuation.com/philadelphia/reviews'

infatuation_review_urls = []


#set up browser and parser
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

browser.visit(infatuation_url)

for x in range(100):
    # retrieve philly restaurant urls
    time.sleep(2)
    browser.find_by_css('.styles_loadMoreButton__GN6yu').first.click()
    html = browser.html
    soup = bs(html, 'html.parser')
    
infatuation_review_urls.append([a['href'] for a in soup.find_all('a', class_="styles_absoluteLink__6MeI8", href=True)])
    

print('Finished')
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# Driver [/Users/noreenjordan/.wdm/drivers/chromedriver/mac64/101.0.4951.41/chromedriver] found in cache
# Finished

# %%
infatuation_review_urls
# Out:
# [['/philadelphia/reviews/spice-finch',
#   '/philadelphia/reviews/bookers-restaurant-bar',
#   '/philadelphia/reviews/jims-south-st',
#   '/philadelphia/reviews/fork',
#   '/philadelphia/reviews/laser-wolf',
#   '/philadelphia/reviews/fiorella-1',
#   '/philadelphia/reviews/suya-suya',
#   '/philadelphia/reviews/barclay-prime',
#   '/philadelphia/reviews/vetri',
#   '/philadelphia/reviews/laurel',
#   '/philadelphia/reviews/vernick-food-drink',
#   '/philadelphia/reviews/friday-saturday-sunday',
#   '/philadelphia/reviews/pizza-shackamaxon',
#   '/philadelphia/reviews/zahav',
#   '/philadelphia/reviews/vedge',
#   '/philadelphia/reviews/attico',
#   '/philadelphia/reviews/beilers-doughnuts',
#   '/philadelphia/reviews/helm',
#   '/philadelphia/reviews/the-dandelion',
#   '/philadelphia/reviews/middle-child-clubhouse',
#   '/philadelphia/reviews/sampan',
#   '/philadelphia/reviews/el-vez',
#   '/philadelphia/reviews/veda',
#   '/philadelphia/reviews/hiroki',
# ...

# %%
philly_reviews_df = pd.DataFrame(infatuation_review_urls)
philly_reviews_df.to_csv('philly_infatuation_review_urls.csv', index=False, encoding='utf-8')
