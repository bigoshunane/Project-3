# %%
import pandas as pd
from currency_converter import CurrencyConverter
import json

c = CurrencyConverter()

# %%
# import csv

michelin = '../data/2021CountryContinent.csv'
michelin_df = pd.read_csv(michelin, encoding='ISO-8859-1')
michelin_df.head()
# Out:
#             ï»¿Name  Year                                            Address  \
# 0      Les Eleveurs  2021                Suikerkaai 1a, Halle, 1500, Belgium
# 1             Ibaya  2021        Carretera General 2, Soldeu, AD100, Andorra
# 2  Celler d'en Toni  2021  Verge del Pilar 4, Andorra la Vella, AD500, An...
# 3            Amador  2021       Grinzinger StraÃe 86, Vienna, 1190, Austria
# 4  SENNS.Restaurant  2021     SÃ¶llheimerstrasse 16, Salzburg, 5020, Austria
#
#                City   Country Continent  MinPrice  MaxPrice Currency  \
# 0             Halle  Alemania    Europe      45.0     145.0      EUR
# 1            Soldeu   Andorra    Europe     110.0     145.0      EUR
# 2  Andorra la Vella   Andorra    Europe      72.0      72.0      EUR
# 3            Vienna   Austria    Europe     265.0     265.0      EUR
# 4          Salzburg   Austria    Europe      85.0     205.0      EUR
#
#                              Cuisine  Longitude   Latitude   PhoneNumber  \
# ...

# %%
# run currency converter function 

def currency_convertor(michelin_df,new_currency='USD'):
    try:
        
        # convert currency and store in new_curr variable
        
        price = michelin_df['MaxPrice']
        curr = michelin_df['Currency']
        new_curr = c.convert(price,curr,new_currency)
        return new_curr
    
    except:
        
        # log incompatible currencies
        
        print(f'{curr} failed')

#add column for max price in USD
michelin_df['max_usd'] = michelin_df.apply(lambda x: currency_convertor(x,new_currency='USD'), axis=1)
# Out:
# MOP failed
# MOP failed
# MOP failed
# MOP failed
# MOP failed
# MOP failed
# MOP failed
# MOP failed
# MOP failed
# MOP failed
# MOP failed
# MOP failed
# MOP failed
# MOP failed
# MOP failed
# MOP failed
# MOP failed
# MOP failed
# MOP failed
# MOP failed
# MOP failed
# MOP failed
# RSD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# TWD failed
# ...

# %%
michelin_df.drop(michelin_df.index[michelin_df['Currency'] == 'TWD'], inplace=True)
michelin_df.drop(michelin_df.index[michelin_df['Currency'] == 'MOP'], inplace=True)

# %%
michelin_df.describe()
# Out:
#          Year       MinPrice       MaxPrice    Longitude     Latitude  \
# count  6356.0    6355.000000    6355.000000  6356.000000  6356.000000
# mean   2021.0    2255.030212    3813.802990    25.027911    41.326786
# std       0.0   10251.068918   18305.980323    64.570857    11.783722
# min    2021.0       2.000000       2.000000  -123.719444   -23.638434
# 25%    2021.0      39.000000      60.000000     0.610879    35.889905
# 50%    2021.0      68.000000     119.000000     7.252956    43.771442
# 75%    2021.0     192.500000     255.000000    18.063563    48.849879
# max    2021.0  200000.000000  380000.000000   139.847604    64.144365
#
#         PhoneNumber      max_usd
# count  6.248000e+03  6354.000000
# mean   3.042516e+11   116.734543
# std    1.523557e+12    88.306253
# min    4.977184e+07     0.601500
# 25%    3.314225e+10    53.851000
# 50%    3.522650e+10    91.314761
# 75%    8.522487e+10   157.131773
# max    4.980000e+13  1402.770525

# %%
# create bins for max_usd and add bin to new column

bins = [0, 55, 100, 160, 200, 1500]
labels = [1,2,3,4,5]
michelin_df['Price'] = pd.cut(michelin_df['max_usd'], bins=bins, labels=labels)

michelin_df
# Out:
#                    ï»¿Name  Year  \
# 0             Les Eleveurs  2021
# 1                    Ibaya  2021
# 2         Celler d'en Toni  2021
# 3                   Amador  2021
# 4         SENNS.Restaurant  2021
# ...                    ...   ...
# 6497     Queenâs English  2021
# 6498  Residents Cafe & Bar  2021
# 6499                 Makan  2021
# 6500                 EllÄ  2021
# 6501   Karma Modern Indian  2021
#
#                                                 Address              City  \
# 0                   Suikerkaai 1a, Halle, 1500, Belgium             Halle
# 1           Carretera General 2, Soldeu, AD100, Andorra            Soldeu
# 2     Verge del Pilar 4, Andorra la Vella, AD500, An...  Andorra la Vella
# 3          Grinzinger StraÃe 86, Vienna, 1190, Austria            Vienna
# 4        SÃ¶llheimerstrasse 16, Salzburg, 5020, Austria          Salzburg
# ...                                                 ...               ...
# ...

# %%
michelin_df = michelin_df.drop(['Year',
                                'MinPrice',
                                'MaxPrice',
                                'Currency',
                                'PhoneNumber',
                                'Url',
                                'max_usd',],
                                axis = 1)

michelin_df = michelin_df.rename(columns={"ï»¿Name": "Restaurant"})

# %%
michelin_df.head()
# Out:
#          Restaurant                                            Address  \
# 0      Les Eleveurs                Suikerkaai 1a, Halle, 1500, Belgium
# 1             Ibaya        Carretera General 2, Soldeu, AD100, Andorra
# 2  Celler d'en Toni  Verge del Pilar 4, Andorra la Vella, AD500, An...
# 3            Amador       Grinzinger StraÃe 86, Vienna, 1190, Austria
# 4  SENNS.Restaurant     SÃ¶llheimerstrasse 16, Salzburg, 5020, Austria
#
#                City   Country Continent                            Cuisine  \
# 0             Halle  Alemania    Europe  Classic Cuisine, Regional Cuisine
# 1            Soldeu   Andorra    Europe           Creative, Modern Cuisine
# 2  Andorra la Vella   Andorra    Europe                       Contemporary
# 3            Vienna   Austria    Europe             Creative, Contemporary
# 4          Salzburg   Austria    Europe                           Creative
#
#    Longitude   Latitude                         WebsiteUrl             Award  \
# ...

# %%
result = michelin_df.to_json(orient="table")
parsed = json.loads(result)
print(json.dumps(parsed, indent=4, sort_keys=True))
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
michelin_df.to_json(r'../data/2021CountryContinent.json',orient="records")
