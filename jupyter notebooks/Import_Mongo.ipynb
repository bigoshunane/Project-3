# %%
import pandas as pd
import pymongo
import json

# %%
# The default port used by MongoDB is 27017

conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

#Read in the csv
df = pd.read_csv("csvs/2021CountryContinent.csv")

# %%
df.shape
# Out:
# (6502, 16)

# %%
# Convert to dictionary
data = df.to_dict(orient = "records")

# %%
data
# Out:
# [{'Name': 'Les Eleveurs',
#   'Year': 2021,
#   'Address': 'Suikerkaai 1a, Halle, 1500, Belgium',
#   'City': 'Halle',
#   'Country': 'Alemania',
#   'Continent': 'Europe',
#   'MinPrice': 45.0,
#   'MaxPrice': 145.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Classic Cuisine, Regional Cuisine',
#   'Longitude': 4.237608,
#   'Latitude': 50.732199,
#   'PhoneNumber': 3223611340.0,
#   'Url': 'https://guide.michelin.com/en/vlaams-brabant/be-halle/restaurant/les-eleveurs',
#   'WebsiteUrl': 'https://www.les-eleveurs.be/',
#   'Award': 'Bib Gourmand'},
#  {'Name': 'Ibaya',
#   'Year': 2021,
#   'Address': 'Carretera General 2, Soldeu, AD100, Andorra',
#   'City': 'Soldeu',
#   'Country': 'Andorra',
#   'Continent': 'Europe',
#   'MinPrice': 110.0,
#   'MaxPrice': 145.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Creative, Modern Cuisine',
#   'Longitude': 1.6709488,
#   'Latitude': 42.5755768,
#   'PhoneNumber': 376870670.0,
#   'Url': 'https://guide.michelin.com/en/canillo/soldeu/restaurant/ibaya',
#   'WebsiteUrl': 'http://www.sporthotels.ad',
#   'Award': '1 MICHELIN Star'},
#  {'Name': "Celler d'en Toni",
#   'Year': 2021,
#   'Address': 'Verge del Pilar 4, Andorra la Vella, AD500, Andorra',
#   'City': 'Andorra la Vella',
#   'Country': 'Andorra',
#   'Continent': 'Europe',
#   'MinPrice': 72.0,
#   'MaxPrice': 72.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Contemporary',
#   'Longitude': 1.531772,
#   'Latitude': 42.507145,
#   'PhoneNumber': 376862750.0,
#   'Url': 'https://guide.michelin.com/en/andorra-la-vella-region/andorra-la-vella/restaurant/celler-d-en-toni',
#   'WebsiteUrl': 'http://www.cellerdentoni.com',
#   'Award': 'Bib Gourmand'},
#  {'Name': 'Amador',
#   'Year': 2021,
#   'Address': 'Grinzinger Straße 86, Vienna, 1190, Austria',
#   'City': 'Vienna',
#   'Country': 'Austria',
#   'Continent': 'Europe',
#   'MinPrice': 265.0,
#   'MaxPrice': 265.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Creative, Contemporary',
#   'Longitude': 16.3586003,
#   'Latitude': 48.2540114,
#   'PhoneNumber': 437000000000.0,
#   'Url': 'https://guide.michelin.com/en/vienna/wien/restaurant/amador',
#   'WebsiteUrl': 'http://www.restaurant-amador.com/',
#   'Award': '3 MICHELIN Stars'},
#  {'Name': 'SENNS.Restaurant',
#   'Year': 2021,
#   'Address': 'Söllheimerstrasse 16, Salzburg, 5020, Austria',
#   'City': 'Salzburg',
#   'Country': 'Austria',
#   'Continent': 'Europe',
#   'MinPrice': 85.0,
#   'MaxPrice': 205.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Creative',
#   'Longitude': 13.0634487,
#   'Latitude': 47.8360718,
#   'PhoneNumber': 437000000000.0,
#   'Url': 'https://guide.michelin.com/en/salzburg-region/salzburg/restaurant/senns-restaurant',
#   'WebsiteUrl': 'https://www.senns.restaurant/',
#   'Award': '2 MICHELIN Stars'},
#  {'Name': 'Ikarus',
#   'Year': 2021,
#   'Address': 'Wilhelm-Spazier-Straße 7a, Salzburg, 5020, Austria',
#   'City': 'Salzburg',
#   'Country': 'Austria',
#   'Continent': 'Europe',
#   'MinPrice': 140.0,
#   'MaxPrice': 210.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Creative',
#   'Longitude': 13.007903,
#   'Latitude': 47.7935605,
#   'PhoneNumber': 4366221970.0,
#   'Url': 'https://guide.michelin.com/en/salzburg-region/salzburg/restaurant/ikarus',
#   'WebsiteUrl': 'https://www.hangar-7.com/',
#   'Award': '2 MICHELIN Stars'},
#  {'Name': 'Silvio Nickol Gourmet Restaurant',
#   'Year': 2021,
#   'Address': 'Coburgbastei 4, Vienna, 1010, Austria',
#   'City': 'Vienna',
#   'Country': 'Austria',
#   'Continent': 'Europe',
#   'MinPrice': 160.0,
#   'MaxPrice': 180.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern Cuisine',
#   'Longitude': 16.3770073,
#   'Latitude': 48.2058003,
#   'PhoneNumber': 43151818130.0,
#   'Url': 'https://guide.michelin.com/en/vienna/wien/restaurant/silvio-nickol-gourmet-restaurant',
#   'WebsiteUrl': 'https://www.palais-coburg.com/',
#   'Award': '2 MICHELIN Stars'},
#  {'Name': 'Steirereck im Stadtpark',
#   'Year': 2021,
#   'Address': 'Am Heumarkt 2a, Vienna, 1030, Austria',
#   'City': 'Vienna',
#   'Country': 'Austria',
#   'Continent': 'Europe',
#   'MinPrice': 135.0,
#   'MaxPrice': 185.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Creative, Contemporary',
#   'Longitude': 16.3815669,
#   'Latitude': 48.2043967,
#   'PhoneNumber': 4317133168.0,
#   'Url': 'https://guide.michelin.com/en/vienna/wien/restaurant/steirereck-im-stadtpark',
#   'WebsiteUrl': 'https://www.steirereck.at/',
#   'Award': '2 MICHELIN Stars'},
#  {'Name': 'Mraz & Sohn',
#   'Year': 2021,
#   'Address': 'Wallensteinstraße 59, Vienna, 1200, Austria',
#   'City': 'Vienna',
#   'Country': 'Austria',
#   'Continent': 'Europe',
#   'MinPrice': 145.0,
#   'MaxPrice': 145.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Creative',
#   'Longitude': 16.3762794,
#   'Latitude': 48.2313246,
#   'PhoneNumber': 4313304594.0,
#   'Url': 'https://guide.michelin.com/en/vienna/wien/restaurant/mraz-sohn',
#   'WebsiteUrl': 'https://www.mrazundsohn.at/',
#   'Award': '2 MICHELIN Stars'},
#  {'Name': 'Konstantin Filippou',
#   'Year': 2021,
#   'Address': 'Dominikanerbastei 17, Vienna, 1010, Austria',
#   'City': 'Vienna',
#   'Country': 'Austria',
#   'Continent': 'Europe',
#   'MinPrice': 56.0,
#   'MaxPrice': 189.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern Cuisine',
#   'Longitude': 16.3797942,
#   'Latitude': 48.2107279,
#   'PhoneNumber': 4315122229.0,
#   'Url': 'https://guide.michelin.com/en/vienna/wien/restaurant/konstantin-filippou',
#   'WebsiteUrl': 'https://www.konstantinfilippou.com/',
#   'Award': '2 MICHELIN Stars'},
#  {'Name': 'Esszimmer',
#   'Year': 2021,
#   'Address': 'Müllner Hauptstraße 33, Salzburg, 5020, Austria',
#   'City': 'Salzburg',
#   'Country': 'Austria',
#   'Continent': 'Europe',
#   'MinPrice': 45.0,
#   'MaxPrice': 128.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Creative, Classic Cuisine',
#   'Longitude': 13.0341933,
#   'Latitude': 47.8066955,
#   'PhoneNumber': 43662870899.0,
#   'Url': 'https://guide.michelin.com/en/salzburg-region/salzburg/restaurant/esszimmer',
#   'WebsiteUrl': 'https://www.esszimmer.com/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'The Glass Garden',
#   'Year': 2021,
#   'Address': 'Mönchsberg Park 26, Salzburg, 5020, Austria',
#   'City': 'Salzburg',
#   'Country': 'Austria',
#   'Continent': 'Europe',
#   'MinPrice': 63.0,
#   'MaxPrice': 163.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern Cuisine',
#   'Longitude': 13.03569,
#   'Latitude': 47.8039566,
#   'PhoneNumber': 437000000000.0,
#   'Url': 'https://guide.michelin.com/en/salzburg-region/salzburg/restaurant/the-glass-garden',
#   'WebsiteUrl': 'https://www.monchstein.at/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'Pfefferschiff',
#   'Year': 2021,
#   'Address': 'Söllheim 3, Salzburg, 5300, Austria',
#   'City': 'Salzburg',
#   'Country': 'Austria',
#   'Continent': 'Europe',
#   'MinPrice': 65.0,
#   'MaxPrice': 189.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Classic Cuisine',
#   'Longitude': 13.0790652,
#   'Latitude': 47.8379197,
#   'PhoneNumber': 43662661242.0,
#   'Url': 'https://guide.michelin.com/en/salzburg-region/salzburg/restaurant/pfefferschiff',
#   'WebsiteUrl': 'https://www.pfefferschiff.at/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'APRON',
#   'Year': 2021,
#   'Address': 'Am Heumarkt 35, Vienna, 1030, Austria',
#   'City': 'Vienna',
#   'Country': 'Austria',
#   'Continent': 'Europe',
#   'MinPrice': 99.0,
#   'MaxPrice': 135.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Creative, Seasonal Cuisine',
#   'Longitude': 16.3767832,
#   'Latitude': 48.199514,
#   'PhoneNumber': 4319074747.0,
#   'Url': 'https://guide.michelin.com/en/vienna/wien/restaurant/apron',
#   'WebsiteUrl': 'https://www.restaurant-apron.at/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'Walter Bauer',
#   'Year': 2021,
#   'Address': 'Sonnenfelsgasse 17, Vienna, 1010, Austria',
#   'City': 'Vienna',
#   'Country': 'Austria',
#   'Continent': 'Europe',
#   'MinPrice': 59.0,
#   'MaxPrice': 79.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Classic Cuisine',
#   'Longitude': 16.3768561,
#   'Latitude': 48.2092406,
#   'PhoneNumber': 4315129871.0,
#   'Url': 'https://guide.michelin.com/en/vienna/wien/restaurant/walter-bauer',
#   'WebsiteUrl': nan,
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'TIAN',
#   'Year': 2021,
#   'Address': 'Himmelpfortgasse 23, Vienna, 1010, Austria',
#   'City': 'Vienna',
#   'Country': 'Austria',
#   'Continent': 'Europe',
#   'MinPrice': 120.0,
#   'MaxPrice': 140.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Vegetarian',
#   'Longitude': 16.3745163,
#   'Latitude': 48.2051767,
#   'PhoneNumber': 4318904665.0,
#   'Url': 'https://guide.michelin.com/en/vienna/wien/restaurant/tian',
#   'WebsiteUrl': 'https://www.tian-restaurant.com/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'SHIKI',
#   'Year': 2021,
#   'Address': 'Krugerstraße 3, Vienna, 1010, Austria',
#   'City': 'Vienna',
#   'Country': 'Austria',
#   'Continent': 'Europe',
#   'MinPrice': 115.0,
#   'MaxPrice': 145.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Japanese',
#   'Longitude': 16.3710135,
#   'Latitude': 48.2041253,
#   'PhoneNumber': 4315127397.0,
#   'Url': 'https://guide.michelin.com/en/vienna/wien/restaurant/shiki',
#   'WebsiteUrl': 'https://www.shiki.at/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'Edvard',
#   'Year': 2021,
#   'Address': 'Schottenring 24, Vienna, 1010, Austria',
#   'City': 'Vienna',
#   'Country': 'Austria',
#   'Continent': 'Europe',
#   'MinPrice': 100.0,
#   'MaxPrice': 138.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Creative, Modern Cuisine',
#   'Longitude': 16.3681893,
#   'Latitude': 48.2162673,
#   'PhoneNumber': 4312361000.0,
#   'Url': 'https://guide.michelin.com/en/vienna/wien/restaurant/edvard',
#   'WebsiteUrl': 'https://www.kempinski.com/vienna',
#   'Award': '1 MICHELIN Star'},
#  {'Name': '[aend]',
#   'Year': 2021,
#   'Address': 'Mollardgasse 76, Vienna, 1060, Austria',
#   'City': 'Vienna',
#   'Country': 'Austria',
#   'Continent': 'Europe',
#   'MinPrice': 155.0,
#   'MaxPrice': 177.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern Cuisine',
#   'Longitude': 16.3410168,
#   'Latitude': 48.1896429,
#   'PhoneNumber': 4315953416.0,
#   'Url': 'https://guide.michelin.com/en/vienna/wien/restaurant/aend',
#   'WebsiteUrl': 'https://www.aend.at/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'Pramerl & the Wolf',
#   'Year': 2021,
#   'Address': 'Pramergasse 21, Vienna, 1090, Austria',
#   'City': 'Vienna',
#   'Country': 'Austria',
#   'Continent': 'Europe',
#   'MinPrice': 110.0,
#   'MaxPrice': 130.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Creative',
#   'Longitude': 16.3648326,
#   'Latitude': 48.2220879,
#   'PhoneNumber': 4319464139.0,
#   'Url': 'https://guide.michelin.com/en/vienna/wien/restaurant/pramerl-the-wolf',
#   'WebsiteUrl': 'https://www.pramerlandthewolf.com/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'Kilian Stuba',
#   'Year': 2021,
#   'Address': 'Oberseitestraße 6, Hirschegg, 6992, Austria',
#   'City': 'Hirschegg',
#   'Country': 'Austria',
#   'Continent': 'Europe',
#   'MinPrice': 110.0,
#   'MaxPrice': 140.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Creative',
#   'Longitude': 10.1719794,
#   'Latitude': 47.3486576,
#   'PhoneNumber': 436000000000.0,
#   'Url': 'https://guide.michelin.com/en/styria/hirschegg/restaurant/kilian-stuba',
#   'WebsiteUrl': 'https://www.travelcharme.com/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'Brandstätter',
#   'Year': 2021,
#   'Address': 'Münchner Bundesstraße 69, Salzburg, 5020, Austria',
#   'City': 'Salzburg',
#   'Country': 'Austria',
#   'Continent': 'Europe',
#   'MinPrice': 75.0,
#   'MaxPrice': 75.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Country cooking, International',
#   'Longitude': 13.010198,
#   'Latitude': 47.8267276,
#   'PhoneNumber': 43662434535.0,
#   'Url': 'https://guide.michelin.com/en/salzburg-region/salzburg/restaurant/brandstatter',
#   'WebsiteUrl': 'https://www.hotel-brandstaetter.com/',
#   'Award': 'Bib Gourmand'},
#  {'Name': 'Gasthof Auerhahn',
#   'Year': 2021,
#   'Address': 'Bahnhofstraße 15, Salzburg, 5020, Austria',
#   'City': 'Salzburg',
#   'Country': 'Austria',
#   'Continent': 'Europe',
#   'MinPrice': 32.0,
#   'MaxPrice': 64.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Country cooking',
#   'Longitude': 13.048637,
#   'Latitude': 47.8206463,
#   'PhoneNumber': 43662451052.0,
#   'Url': 'https://guide.michelin.com/en/salzburg-region/salzburg/restaurant/gasthof-auerhahn',
#   'WebsiteUrl': 'https://www.auerhahn-salzburg.at/',
#   'Award': 'Bib Gourmand'},
#  {'Name': 'Reinhartshuber Im Gwandhaus',
#   'Year': 2021,
#   'Address': 'Morzger Straße 31, Salzburg, 5020, Austria',
#   'City': 'Salzburg',
#   'Country': 'Austria',
#   'Continent': 'Europe',
#   'MinPrice': 31.0,
#   'MaxPrice': 84.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Classic Cuisine',
#   'Longitude': 13.0576525,
#   'Latitude': 47.7793078,
#   'PhoneNumber': 4370000000000.0,
#   'Url': 'https://guide.michelin.com/en/salzburg-region/salzburg/restaurant/reinhartshuber-im-gwandhaus',
#   'WebsiteUrl': 'http://www.restaurant-reinhartshuber.at',
#   'Award': 'Bib Gourmand'},
#  {'Name': 'DiningRuhm',
#   'Year': 2021,
#   'Address': 'Lambrechtgasse 9, Vienna, 1040, Austria',
#   'City': 'Vienna',
#   'Country': 'Austria',
#   'Continent': 'Europe',
#   'MinPrice': 29.0,
#   'MaxPrice': 115.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Fusion',
#   'Longitude': 16.3647424,
#   'Latitude': 48.1903564,
#   'PhoneNumber': 4319452224.0,
#   'Url': 'https://guide.michelin.com/en/vienna/wien/restaurant/diningruhm',
#   'WebsiteUrl': 'https://www.diningruhm.at/',
#   'Award': 'Bib Gourmand'},
#  {'Name': 'MAST Weinbistro',
#   'Year': 2021,
#   'Address': 'Porzellangasse 53, Vienna, 1090, Austria',
#   'City': 'Vienna',
#   'Country': 'Austria',
#   'Continent': 'Europe',
#   'MinPrice': 43.0,
#   'MaxPrice': 69.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Austrian',
#   'Longitude': 16.361521,
#   'Latitude': 48.2249667,
#   'PhoneNumber': 4319226679.0,
#   'Url': 'https://guide.michelin.com/en/vienna/wien/restaurant/mast-weinbistro',
#   'WebsiteUrl': 'https://www.mast.wine/',
#   'Award': 'Bib Gourmand'},
#  {'Name': 'Vestibül',
#   'Year': 2021,
#   'Address': 'Universitätsring 2, Vienna, 1010, Austria',
#   'City': 'Vienna',
#   'Country': 'Austria',
#   'Continent': 'Europe',
#   'MinPrice': 33.0,
#   'MaxPrice': 89.0,
#   'Currency': 'EUR',
#   'Cuisine': 'International',
#   'Longitude': 16.3613574,
#   'Latitude': 48.2107038,
#   'PhoneNumber': 4315324999.0,
#   'Url': 'https://guide.michelin.com/en/vienna/wien/restaurant/vestibul',
#   'WebsiteUrl': 'https://www.vestibuel.at/',
#   'Award': 'Bib Gourmand'},
#  {'Name': 'Woracziczky',
#   'Year': 2021,
#   'Address': 'Spengergasse 52, Vienna, 1010, Austria',
#   'City': 'Vienna',
#   'Country': 'Austria',
#   'Continent': 'Europe',
#   'MinPrice': 47.0,
#   'MaxPrice': 47.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Austrian',
#   'Longitude': 16.3530588,
#   'Latitude': 48.189256,
#   'PhoneNumber': 4370000000000.0,
#   'Url': 'https://guide.michelin.com/en/vienna/wien/restaurant/woracziczky',
#   'WebsiteUrl': 'http://www.woracziczky.at/',
#   'Award': 'Bib Gourmand'},
#  {'Name': 'Meierei im Stadtpark',
#   'Year': 2021,
#   'Address': 'Am Heumarkt 2a, Vienna, 1030, Austria',
#   'City': 'Vienna',
#   'Country': 'Austria',
#   'Continent': 'Europe',
#   'MinPrice': 50.0,
#   'MaxPrice': 70.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Austrian',
#   'Longitude': 16.3812147,
#   'Latitude': 48.2045107,
#   'PhoneNumber': 432000000000.0,
#   'Url': 'https://guide.michelin.com/en/vienna/wien/restaurant/meierei-im-stadtpark',
#   'WebsiteUrl': 'https://www.steirereck.at/',
#   'Award': 'Bib Gourmand'},
#  {'Name': 'Mochi',
#   'Year': 2021,
#   'Address': 'Praterstraße 15, Vienna, 1020, Austria',
#   'City': 'Vienna',
#   'Country': 'Austria',
#   'Continent': 'Europe',
#   'MinPrice': 30.0,
#   'MaxPrice': 60.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Japanese',
#   'Longitude': 16.3818079,
#   'Latitude': 48.2135968,
#   'PhoneNumber': 4319251380.0,
#   'Url': 'https://guide.michelin.com/en/vienna/wien/restaurant/mochi',
#   'WebsiteUrl': 'https://www.mochi.at/',
#   'Award': 'Bib Gourmand'},
#  {'Name': 'Gasthaus Seidl',
#   'Year': 2021,
#   'Address': 'Ungargasse 63, Vienna, 1030, Austria',
#   'City': 'Vienna',
#   'Country': 'Austria',
#   'Continent': 'Europe',
#   'MinPrice': 39.0,
#   'MaxPrice': 59.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Traditional Cuisine, Market Cuisine',
#   'Longitude': 16.3873555,
#   'Latitude': 48.1973068,
#   'PhoneNumber': 4317131781.0,
#   'Url': 'https://guide.michelin.com/en/vienna/wien/restaurant/gasthaus-seidl',
#   'WebsiteUrl': 'https://www.gasthaus-seidl.at/',
#   'Award': 'Bib Gourmand'},
#  {'Name': 'Carnozet',
#   'Year': 2021,
#   'Address': 'Oberseitestraße 6, Hirschegg, 6992, Austria',
#   'City': 'Hirschegg',
#   'Country': 'Austria',
#   'Continent': 'Europe',
#   'MinPrice': 39.0,
#   'MaxPrice': 59.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Country cooking',
#   'Longitude': 10.1717676,
#   'Latitude': 47.3486478,
#   'PhoneNumber': 4355176080.0,
#   'Url': 'https://guide.michelin.com/en/styria/hirschegg/restaurant/carnozet',
#   'WebsiteUrl': 'https://www.travelcharme.com/',
#   'Award': 'Bib Gourmand'},
#  {'Name': 'Humbachstube im Alpenhof Jäger',
#   'Year': 2021,
#   'Address': 'Unterwestegg 17, Riezlern, 6991, Austria',
#   'City': 'Riezlern',
#   'Country': 'Austria',
#   'Continent': 'Europe',
#   'MinPrice': 39.0,
#   'MaxPrice': 95.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Country cooking',
#   'Longitude': 10.1996801,
#   'Latitude': 47.3668156,
#   'PhoneNumber': 4355175234.0,
#   'Url': 'https://guide.michelin.com/en/vorarlberg/riezlern/restaurant/humbachstube-im-alpenhof-jager',
#   'WebsiteUrl': 'https://www.alpenhof-jaeger.de/',
#   'Award': 'Bib Gourmand'},
#  {'Name': 'Zilte',
#   'Year': 2021,
#   'Address': 'Hanzestedenplaats 5, Antwerpen, 2000, Belgium',
#   'City': 'Antwerpen',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 195.0,
#   'MaxPrice': 330.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Creative',
#   'Longitude': 4.4049639,
#   'Latitude': 51.2287189,
#   'PhoneNumber': 3232834040.0,
#   'Url': 'https://guide.michelin.com/en/antwerpen/be-antwerpen/restaurant/t-zilte',
#   'WebsiteUrl': 'https://www.zilte.be/',
#   'Award': '3 MICHELIN Stars'},
#  {'Name': 'Hof van Cleve',
#   'Year': 2021,
#   'Address': 'Riemegemstraat 1, Kruishoutem, 9770, Belgium',
#   'City': 'Kruishoutem',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 295.0,
#   'MaxPrice': 530.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Creative',
#   'Longitude': 3.5098648,
#   'Latitude': 50.9039501,
#   'PhoneNumber': 3293835848.0,
#   'Url': 'https://guide.michelin.com/en/oost-vlaanderen/kruishoutem/restaurant/hof-van-cleve',
#   'WebsiteUrl': 'https://www.hofvancleve.com/',
#   'Award': '3 MICHELIN Stars'},
#  {'Name': 'bon bon',
#   'Year': 2021,
#   'Address': 'avenue de Tervueren 453, Woluwe-Saint-Pierre, 1150, Belgium',
#   'City': 'Woluwe-Saint-Pierre',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 235.0,
#   'MaxPrice': 245.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Creative, Organic',
#   'Longitude': 4.44663,
#   'Latitude': 50.822776,
#   'PhoneNumber': 3223466615.0,
#   'Url': 'https://guide.michelin.com/en/bruxelles-capitale/woluwe-saint-pierre/restaurant/bon-bon',
#   'WebsiteUrl': 'https://www.restaurant-bon-bon.be/',
#   'Award': '2 MICHELIN Stars'},
#  {'Name': 'De Jonkman',
#   'Year': 2021,
#   'Address': 'Maalsesteenweg 438, Sint-Kruis, 8310, Belgium',
#   'City': 'Sint-Kruis',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 75.0,
#   'MaxPrice': 315.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Creative',
#   'Longitude': 3.2777835,
#   'Latitude': 51.207236,
#   'PhoneNumber': 3250360767.0,
#   'Url': 'https://guide.michelin.com/en/west-vlaanderen/sint-kruis/restaurant/de-jonkman',
#   'WebsiteUrl': 'https://www.dejonkman.be/',
#   'Award': '2 MICHELIN Stars'},
#  {'Name': "d'Eugénie à Emilie",
#   'Year': 2021,
#   'Address': 'place de la Résistance 1, Baudour, 7331, Belgium',
#   'City': 'Baudour',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 85.0,
#   'MaxPrice': 170.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Classic French, Traditional Cuisine',
#   'Longitude': 3.8379089,
#   'Latitude': 50.4833038,
#   'PhoneNumber': 3265613170.0,
#   'Url': 'https://guide.michelin.com/en/hainaut/baudour/restaurant/d-eugenie-a-emilie',
#   'WebsiteUrl': 'http://www.fernez.com/deugenie-a-emilie',
#   'Award': '2 MICHELIN Stars'},
#  {'Name': "L'Eau Vive",
#   'Year': 2021,
#   'Address': 'route de Floreffe 37, Arbre, 5170, Belgium',
#   'City': 'Arbre',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 60.0,
#   'MaxPrice': 165.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern French, Modern Cuisine',
#   'Longitude': 4.8469885,
#   'Latitude': 50.3636851,
#   'PhoneNumber': 3281411151.0,
#   'Url': 'https://guide.michelin.com/en/namur/arbre/restaurant/l-eau-vive',
#   'WebsiteUrl': 'https://www.eau-vive.be/',
#   'Award': '2 MICHELIN Stars'},
#  {'Name': 'Hostellerie Le Fox',
#   'Year': 2021,
#   'Address': 'Walckierstraat 2, De Panne, 8660, Belgium',
#   'City': 'De Panne',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 69.0,
#   'MaxPrice': 180.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Creative French',
#   'Longitude': 2.591914,
#   'Latitude': 51.1035368,
#   'PhoneNumber': 3258412855.0,
#   'Url': 'https://guide.michelin.com/en/west-vlaanderen/de-panne/restaurant/hostellerie-le-fox',
#   'WebsiteUrl': 'http://www.hotelfox.be/',
#   'Award': '2 MICHELIN Stars'},
#  {'Name': 'Nuance',
#   'Year': 2021,
#   'Address': 'Kiliaanstraat 8, Duffel, 2570, Belgium',
#   'City': 'Duffel',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 75.0,
#   'MaxPrice': 215.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Creative',
#   'Longitude': 4.505835,
#   'Latitude': 51.0957136,
#   'PhoneNumber': 3215634265.0,
#   'Url': 'https://guide.michelin.com/en/antwerpen/duffel/restaurant/nuance',
#   'WebsiteUrl': 'https://www.resto-nuance.be/',
#   'Award': '2 MICHELIN Stars'},
#  {'Name': 'La Durée',
#   'Year': 2021,
#   'Address': 'Leenstraat 28, Izegem, 8870, Belgium',
#   'City': 'Izegem',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 100.0,
#   'MaxPrice': 232.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Creative, Modern Cuisine',
#   'Longitude': 3.1957708,
#   'Latitude': 50.9120191,
#   'PhoneNumber': 3251310031.0,
#   'Url': 'https://guide.michelin.com/en/west-vlaanderen/izegem/restaurant/la-duree',
#   'WebsiteUrl': 'https://www.laduree.be/',
#   'Award': '2 MICHELIN Stars'},
#  {'Name': "L'Air du Temps",
#   'Year': 2021,
#   'Address': 'rue de la Croix Monet 2, Liernu, 5310, Belgium',
#   'City': 'Liernu',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 95.0,
#   'MaxPrice': 210.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Creative, Modern Cuisine',
#   'Longitude': 4.8329862,
#   'Latitude': 50.5927328,
#   'PhoneNumber': 3281813048.0,
#   'Url': 'https://guide.michelin.com/en/namur/liernu/restaurant/l-air-du-temps371956',
#   'WebsiteUrl': 'https://www.airdutemps.be/',
#   'Award': '2 MICHELIN Stars'},
#  {'Name': 'Le Chalet de la Forêt',
#   'Year': 2021,
#   'Address': 'drêve de Lorraine 43, Uccle, 1180, Belgium',
#   'City': 'Uccle',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 79.0,
#   'MaxPrice': 207.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Creative',
#   'Longitude': 4.3868414,
#   'Latitude': 50.7842411,
#   'PhoneNumber': 3223745416.0,
#   'Url': 'https://guide.michelin.com/en/bruxelles-capitale/uccle/restaurant/le-chalet-de-la-foret',
#   'WebsiteUrl': 'https://www.lechaletdelaforet.be/',
#   'Award': '2 MICHELIN Stars'},
#  {'Name': 'Bartholomeus',
#   'Year': 2021,
#   'Address': 'Zeedijk 267, Heist, 8301, Belgium',
#   'City': 'Heist',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 210.0,
#   'MaxPrice': 210.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern Cuisine',
#   'Longitude': 3.2436215,
#   'Latitude': 51.341769,
#   'PhoneNumber': 3250517576.0,
#   'Url': 'https://guide.michelin.com/en/west-vlaanderen/heist/restaurant/bartholomeus',
#   'WebsiteUrl': 'https://www.restaurantbartholomeus.be/',
#   'Award': '2 MICHELIN Stars'},
#  {'Name': 'Vrijmoed',
#   'Year': 2021,
#   'Address': 'Vlaanderenstraat 22, Gent, 9000, Belgium',
#   'City': 'Gent',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 69.0,
#   'MaxPrice': 203.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Creative, Modern Cuisine',
#   'Longitude': 3.7288256,
#   'Latitude': 51.0511061,
#   'PhoneNumber': 3292799977.0,
#   'Url': 'https://guide.michelin.com/en/oost-vlaanderen/gent/restaurant/vrijmoed',
#   'WebsiteUrl': 'https://www.vrijmoed.be/',
#   'Award': '2 MICHELIN Stars'},
#  {'Name': 'The Jane',
#   'Year': 2021,
#   'Address': 'Paradeplein 1, Antwerpen, 2018, Belgium',
#   'City': 'Antwerpen',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 230.0,
#   'MaxPrice': 230.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Creative',
#   'Longitude': 4.4233593,
#   'Latitude': 51.2023273,
#   'PhoneNumber': 3238084465.0,
#   'Url': 'https://guide.michelin.com/en/antwerpen/be-antwerpen/restaurant/the-jane',
#   'WebsiteUrl': 'https://www.thejaneantwerp.com/',
#   'Award': '2 MICHELIN Stars'},
#  {'Name': 'Ralf Berendsen',
#   'Year': 2021,
#   'Address': 'Paalsteenlaan 90, Neerharen, 3620, Belgium',
#   'City': 'Neerharen',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 130.0,
#   'MaxPrice': 245.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Creative',
#   'Longitude': 5.6676398,
#   'Latitude': 50.9152264,
#   'PhoneNumber': 3289739770.0,
#   'Url': 'https://guide.michelin.com/en/be-limburg/neerharen/restaurant/ralf-berendsen',
#   'WebsiteUrl': 'https://www.labutteauxbois.be/restaurant-ralfberendsen/',
#   'Award': '2 MICHELIN Stars'},
#  {'Name': 'La Table de Maxime',
#   'Year': 2021,
#   'Address': 'Our 23, Our, 6852, Belgium',
#   'City': 'Our',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 70.0,
#   'MaxPrice': 167.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern Cuisine',
#   'Longitude': 5.122613,
#   'Latitude': 49.959957,
#   'PhoneNumber': 3261239510.0,
#   'Url': 'https://guide.michelin.com/en/be-luxembourg/our/restaurant/la-table-de-maxime',
#   'WebsiteUrl': 'https://www.maximecollard.be/',
#   'Award': '2 MICHELIN Stars'},
#  {'Name': 'Comme chez Soi',
#   'Year': 2021,
#   'Address': 'place Rouppe 23, Brussels, 1000, Belgium',
#   'City': 'Brussels',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 69.0,
#   'MaxPrice': 298.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Classic Cuisine',
#   'Longitude': 4.3459079,
#   'Latitude': 50.8423511,
#   'PhoneNumber': 3225122921.0,
#   'Url': 'https://guide.michelin.com/en/bruxelles-capitale/bruxelles/restaurant/comme-chez-soi113872',
#   'WebsiteUrl': 'https://www.commechezsoi.be/',
#   'Award': '2 MICHELIN Stars'},
#  {'Name': 'Boury',
#   'Year': 2021,
#   'Address': 'Rumbeeksesteenweg 300, Roeselare, 8800, Belgium',
#   'City': 'Roeselare',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 100.0,
#   'MaxPrice': 160.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Creative French',
#   'Longitude': 3.1403981,
#   'Latitude': 50.9374466,
#   'PhoneNumber': 3251626462.0,
#   'Url': 'https://guide.michelin.com/en/west-vlaanderen/roeselare/restaurant/boury',
#   'WebsiteUrl': 'https://www.restaurantboury.be/',
#   'Award': '2 MICHELIN Stars'},
#  {'Name': 'Slagmolen',
#   'Year': 2021,
#   'Address': 'Molenweg 177, Opglabbeek, 3660, Belgium',
#   'City': 'Opglabbeek',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 80.0,
#   'MaxPrice': 185.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Traditional Cuisine',
#   'Longitude': 5.6159232,
#   'Latitude': 51.0431658,
#   'PhoneNumber': 3289854888.0,
#   'Url': 'https://guide.michelin.com/en/be-limburg/opglabbeek/restaurant/slagmolen',
#   'WebsiteUrl': 'https://www.slagmolen.be/',
#   'Award': '2 MICHELIN Stars'},
#  {'Name': 'Hostellerie St-Nicolas',
#   'Year': 2021,
#   'Address': 'Veurnseweg 532, Elverdinge, 8906, Belgium',
#   'City': 'Elverdinge',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 55.0,
#   'MaxPrice': 195.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Creative',
#   'Longitude': 2.818281,
#   'Latitude': 50.8857292,
#   'PhoneNumber': 3257200622.0,
#   'Url': 'https://guide.michelin.com/en/west-vlaanderen/elverdinge/restaurant/hostellerie-st-nicolas',
#   'WebsiteUrl': 'https://www.hostellerie-stnicolas.com/',
#   'Award': '2 MICHELIN Stars'},
#  {'Name': 'Castor',
#   'Year': 2021,
#   'Address': 'Kortrijkseweg 164, Beveren-Leie, 8791, Belgium',
#   'City': 'Beveren-Leie',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 55.0,
#   'MaxPrice': 161.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern French',
#   'Longitude': 3.3430165,
#   'Latitude': 50.8720569,
#   'PhoneNumber': 3256190121.0,
#   'Url': 'https://guide.michelin.com/en/west-vlaanderen/beveren-leie/restaurant/castor',
#   'WebsiteUrl': 'https://www.cas-tor.be/',
#   'Award': '2 MICHELIN Stars'},
#  {'Name': 'Pastorale',
#   'Year': 2021,
#   'Address': 'Laarstraat 22, Reet, 2840, Belgium',
#   'City': 'Reet',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 85.0,
#   'MaxPrice': 195.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Creative',
#   'Longitude': 4.4152963,
#   'Latitude': 51.1008376,
#   'PhoneNumber': 3238446526.0,
#   'Url': 'https://guide.michelin.com/en/antwerpen/reet/restaurant/pastorale',
#   'WebsiteUrl': 'https://www.depastorale.be/',
#   'Award': '2 MICHELIN Stars'},
#  {'Name': 'Château du Mylord',
#   'Year': 2021,
#   'Address': 'rue Saint-Mortier 35, Ellezelles, 7890, Belgium',
#   'City': 'Ellezelles',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 95.0,
#   'MaxPrice': 270.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Contemporary',
#   'Longitude': 3.6736201,
#   'Latitude': 50.7298541,
#   'PhoneNumber': 3268542602.0,
#   'Url': 'https://guide.michelin.com/en/hainaut/ellezelles/restaurant/chateau-du-mylord',
#   'WebsiteUrl': 'https://www.mylord.be/',
#   'Award': '2 MICHELIN Stars'},
#  {'Name': 'Cuchara',
#   'Year': 2021,
#   'Address': 'Lepelstraat 3, Lommel, 3920, Belgium',
#   'City': 'Lommel',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 175.0,
#   'MaxPrice': 215.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Creative, Modern Cuisine',
#   'Longitude': 5.3097212,
#   'Latitude': 51.2309534,
#   'PhoneNumber': 3211757435.0,
#   'Url': 'https://guide.michelin.com/en/be-limburg/lommel/restaurant/cuchara',
#   'WebsiteUrl': 'https://www.cuchara.be/',
#   'Award': '2 MICHELIN Stars'},
#  {'Name': 'La Paix',
#   'Year': 2021,
#   'Address': 'rue Ropsy-Chaudron 49, Anderlecht, 1070, Belgium',
#   'City': 'Anderlecht',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 105.0,
#   'MaxPrice': 235.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Asian Influences, Creative',
#   'Longitude': 4.3281195,
#   'Latitude': 50.8437035,
#   'PhoneNumber': 3225230958.0,
#   'Url': 'https://guide.michelin.com/en/bruxelles-capitale/anderlecht/restaurant/la-paix203164',
#   'WebsiteUrl': 'https://www.lapaix.eu/',
#   'Award': '2 MICHELIN Stars'},
#  {'Name': 'Le Comptoir de Marie',
#   'Year': 2021,
#   'Address': "rue d'Enghien 8, Mons, 7000, Belgium",
#   'City': 'Mons',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 30.0,
#   'MaxPrice': 75.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Spanish',
#   'Longitude': 3.951299,
#   'Latitude': 50.4545069,
#   'PhoneNumber': 3265872949.0,
#   'Url': 'https://guide.michelin.com/en/hainaut/mons/restaurant/le-comptoir-de-marie',
#   'WebsiteUrl': 'https://www.lecomptoirdemarie.be/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': "The Butcher's son",
#   'Year': 2021,
#   'Address': 'Boomgaardstraat 1, Antwerpen, 2018, Belgium',
#   'City': 'Antwerpen',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 68.0,
#   'MaxPrice': 94.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Traditional Cuisine, Meats and Grills',
#   'Longitude': 4.4157849,
#   'Latitude': 51.1994236,
#   'PhoneNumber': 3232301638.0,
#   'Url': 'https://guide.michelin.com/en/antwerpen/be-antwerpen/restaurant/the-butcher-s-son',
#   'WebsiteUrl': 'https://www.thebutchersson.be/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': "'t Fornuis",
#   'Year': 2021,
#   'Address': 'Reyndersstraat 24, Antwerpen, 2000, Belgium',
#   'City': 'Antwerpen',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 150.0,
#   'MaxPrice': 150.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Classic Cuisine',
#   'Longitude': 4.3994483,
#   'Latitude': 51.2190389,
#   'PhoneNumber': 3232336270.0,
#   'Url': 'https://guide.michelin.com/en/antwerpen/be-antwerpen/restaurant/t-fornuis',
#   'WebsiteUrl': nan,
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'San Daniele',
#   'Year': 2021,
#   'Address': 'avenue Charles-Quint 6, Ganshoren, 1083, Belgium',
#   'City': 'Ganshoren',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 55.0,
#   'MaxPrice': 140.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Italian',
#   'Longitude': 4.3133929,
#   'Latitude': 50.8682699,
#   'PhoneNumber': 3224267923.0,
#   'Url': 'https://guide.michelin.com/en/bruxelles-capitale/ganshoren/restaurant/san-daniele',
#   'WebsiteUrl': 'https://www.san-daniele.be/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'Libertine',
#   'Year': 2021,
#   'Address': 'Oudenaardsesteenweg 32, Erpe, 9420, Belgium',
#   'City': 'Erpe',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 48.0,
#   'MaxPrice': 175.0,
#   'Currency': 'EUR',
#   'Cuisine': 'French, Seasonal Cuisine',
#   'Longitude': 3.9900792,
#   'Latitude': 50.9408064,
#   'PhoneNumber': 3253410268.0,
#   'Url': 'https://guide.michelin.com/en/oost-vlaanderen/erpe/restaurant/libertine',
#   'WebsiteUrl': 'https://www.restaurantlibertine.be/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': "L'Envie",
#   'Year': 2021,
#   'Address': 'Helkijnstraat 38, Sint-Denijs, 8554, Belgium',
#   'City': 'Sint-Denijs',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 44.0,
#   'MaxPrice': 105.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern French',
#   'Longitude': 3.3705692,
#   'Latitude': 50.7499139,
#   'PhoneNumber': 3256221983.0,
#   'Url': 'https://guide.michelin.com/en/west-vlaanderen/sint-denijs/restaurant/l-envie',
#   'WebsiteUrl': 'https://www.lenvie-restaurant.be/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'Cuines,33',
#   'Year': 2021,
#   'Address': 'Smedenstraat 33, Knokke, 8300, Belgium',
#   'City': 'Knokke',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 58.0,
#   'MaxPrice': 125.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Creative',
#   'Longitude': 3.2879658,
#   'Latitude': 51.3394371,
#   'PhoneNumber': 3250606069.0,
#   'Url': 'https://guide.michelin.com/en/west-vlaanderen/knokke/restaurant/cuines-33',
#   'WebsiteUrl': 'https://www.cuines33.be/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'Aux petits oignons',
#   'Year': 2021,
#   'Address': 'chaussée de Tirlemont 260, Jodoigne, 1370, Belgium',
#   'City': 'Jodoigne',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 37.0,
#   'MaxPrice': 88.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern Cuisine',
#   'Longitude': 4.879794,
#   'Latitude': 50.7418915,
#   'PhoneNumber': 3210760078.0,
#   'Url': 'https://guide.michelin.com/en/brabant-wallon/jodoigne/restaurant/aux-petits-oignons',
#   'WebsiteUrl': 'https://www.auxpetitsoignons.be/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': "Zet'Joe by Geert Van Hecke",
#   'Year': 2021,
#   'Address': 'Langestraat 11, Brugge, 8000, Belgium',
#   'City': 'Brugge',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 73.0,
#   'MaxPrice': 147.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Creative French',
#   'Longitude': 3.2321611,
#   'Latitude': 51.2097162,
#   'PhoneNumber': 3250338259.0,
#   'Url': 'https://guide.michelin.com/en/west-vlaanderen/brugge/restaurant/zet-joe-by-geert-van-hecke',
#   'WebsiteUrl': 'https://www.zetjoe.be/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': "'t Korennaer",
#   'Year': 2021,
#   'Address': 'Nieuwkerkenstraat 4, Nieuwkerken-Waas, 9100, Belgium',
#   'City': 'Nieuwkerken-Waas',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 55.0,
#   'MaxPrice': 125.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern Cuisine',
#   'Longitude': 4.1781069,
#   'Latitude': 51.1929468,
#   'PhoneNumber': 3237780845.0,
#   'Url': 'https://guide.michelin.com/en/oost-vlaanderen/nieuwkerken-waas/restaurant/t-korennaer',
#   'WebsiteUrl': 'https://www.korennaer.be/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'Benoit en Bernard Dewitte',
#   'Year': 2021,
#   'Address': 'Beertegemstraat 52, Ouwegem, 9750, Belgium',
#   'City': 'Ouwegem',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 77.0,
#   'MaxPrice': 117.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern French',
#   'Longitude': 3.606346,
#   'Latitude': 50.9133244,
#   'PhoneNumber': 3293845652.0,
#   'Url': 'https://guide.michelin.com/en/oost-vlaanderen/ouwegem/restaurant/benoit-en-bernard-dewitte',
#   'WebsiteUrl': 'https://www.benoitdewitte.be/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'Philippe Fauchet',
#   'Year': 2021,
#   'Address': 'rue de Warfée 62, Saint-Georges-sur-Meuse, 4470, Belgium',
#   'City': 'Saint-Georges-sur-Meuse',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 65.0,
#   'MaxPrice': 135.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Creative',
#   'Longitude': 5.3712656,
#   'Latitude': 50.6096505,
#   'PhoneNumber': 3242595939.0,
#   'Url': 'https://guide.michelin.com/en/liege/saint-georges-sur-meuse/restaurant/philippe-fauchet',
#   'WebsiteUrl': 'https://www.philippefauchet.be/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': "l'Essentiel",
#   'Year': 2021,
#   'Address': 'rue Roger Clément 32, Temploux, 5020, Belgium',
#   'City': 'Temploux',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 39.0,
#   'MaxPrice': 94.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Creative French',
#   'Longitude': 4.7387117,
#   'Latitude': 50.4754247,
#   'PhoneNumber': 3281568616.0,
#   'Url': 'https://guide.michelin.com/en/namur/temploux/restaurant/l-essentiel210192',
#   'WebsiteUrl': 'https://www.lessentiel.be/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'Bistrot du Nord',
#   'Year': 2021,
#   'Address': 'Lange Dijkstraat 36, Antwerpen, 2060, Belgium',
#   'City': 'Antwerpen',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 145.0,
#   'MaxPrice': 145.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Traditional Cuisine',
#   'Longitude': 4.418618,
#   'Latitude': 51.227654,
#   'PhoneNumber': 3232334549.0,
#   'Url': 'https://guide.michelin.com/en/antwerpen/be-antwerpen/restaurant/bistrot-du-nord',
#   'WebsiteUrl': 'https://www.bistrotdunord.be/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'Alain Bianchin',
#   'Year': 2021,
#   'Address': 'Brusselsesteenweg 663, Overijse, 3090, Belgium',
#   'City': 'Overijse',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 48.0,
#   'MaxPrice': 160.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern French, Creative French',
#   'Longitude': 4.4819428,
#   'Latitude': 50.793583,
#   'PhoneNumber': 3226576788.0,
#   'Url': 'https://guide.michelin.com/en/vlaams-brabant/overijse/restaurant/alain-bianchin',
#   'WebsiteUrl': 'https://www.alainbianchin.be/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'EED',
#   'Year': 2021,
#   'Address': 'Vaartstraat 14, Leuven, 3000, Belgium',
#   'City': 'Leuven',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 115.0,
#   'MaxPrice': 115.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern Cuisine',
#   'Longitude': 4.7024848,
#   'Latitude': 50.880639,
#   'PhoneNumber': 3216190614.0,
#   'Url': 'https://guide.michelin.com/en/vlaams-brabant/leuven/restaurant/eed',
#   'WebsiteUrl': 'https://www.eedleuven.be/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'Hostellerie Le Prieuré Saint-Géry',
#   'Year': 2021,
#   'Address': 'rue Lambot 9, Solre-Saint-Géry, 6500, Belgium',
#   'City': 'Solre-Saint-Géry',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 55.0,
#   'MaxPrice': 130.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Creative',
#   'Longitude': 4.2434926,
#   'Latitude': 50.2176067,
#   'PhoneNumber': 3271589700.0,
#   'Url': 'https://guide.michelin.com/en/hainaut/solre-saint-gry/restaurant/hostellerie-le-prieure-saint-gery',
#   'WebsiteUrl': 'https://www.prieurestgery.be/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'Hofke van Bazel',
#   'Year': 2021,
#   'Address': 'Koningin Astridplein 11, Bazel, 9150, Belgium',
#   'City': 'Bazel',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 48.0,
#   'MaxPrice': 124.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Market Cuisine, Seasonal Cuisine',
#   'Longitude': 4.3002815,
#   'Latitude': 51.1471664,
#   'PhoneNumber': 3237441140.0,
#   'Url': 'https://guide.michelin.com/en/oost-vlaanderen/bazel/restaurant/hofke-van-bazel',
#   'WebsiteUrl': 'https://www.hofkevanbazel.be/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'La Canne en Ville',
#   'Year': 2021,
#   'Address': 'rue de la Réforme 22, Ixelles, 1050, Belgium',
#   'City': 'Ixelles',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 57.0,
#   'MaxPrice': 163.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Market Cuisine',
#   'Longitude': 4.3561099,
#   'Latitude': 50.8204237,
#   'PhoneNumber': 3223472926.0,
#   'Url': 'https://guide.michelin.com/en/bruxelles-capitale/ixelles/restaurant/la-canne-en-ville',
#   'WebsiteUrl': 'https://www.lacanneenville.be/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'Vol-Ver',
#   'Year': 2021,
#   'Address': 'Watervalstraat 23, Marke, 8510, Belgium',
#   'City': 'Marke',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 45.0,
#   'MaxPrice': 95.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Traditional Cuisine',
#   'Longitude': 3.2351421,
#   'Latitude': 50.7970808,
#   'PhoneNumber': 3256498592.0,
#   'Url': 'https://guide.michelin.com/en/west-vlaanderen/marke/restaurant/vol-ver',
#   'WebsiteUrl': 'https://www.vol-ver.be/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'Sir Kwinten',
#   'Year': 2021,
#   'Address': 'Markt 9a, Sint-Kwintens-Lennik, 1750, Belgium',
#   'City': 'Sint-Kwintens-Lennik',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 49.0,
#   'MaxPrice': 115.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern Cuisine',
#   'Longitude': 4.1554453,
#   'Latitude': 50.8056605,
#   'PhoneNumber': 3225828992.0,
#   'Url': 'https://guide.michelin.com/en/vlaams-brabant/sint-kwintens-lennik/restaurant/sir-kwinten',
#   'WebsiteUrl': 'https://www.sirkwinten.be/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'Le Pré des Oréades',
#   'Year': 2021,
#   'Address': 'avenue du Professeur Henrijean 143, Spa, 4900, Belgium',
#   'City': 'Spa',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 58.0,
#   'MaxPrice': 89.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Classic French',
#   'Longitude': 5.8513194,
#   'Latitude': 50.4805268,
#   'PhoneNumber': 3287771866.0,
#   'Url': 'https://guide.michelin.com/en/liege/spa/restaurant/le-pre-des-oreades',
#   'WebsiteUrl': 'https://www.lepredesoreades.be/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'Le Cor de Chasse',
#   'Year': 2021,
#   'Address': 'rue des Combattants 16, Wéris, 6940, Belgium',
#   'City': 'Wéris',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 45.0,
#   'MaxPrice': 105.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Creative',
#   'Longitude': 5.52895,
#   'Latitude': 50.32426,
#   'PhoneNumber': 3286211498.0,
#   'Url': 'https://guide.michelin.com/en/be-luxembourg/wris/restaurant/le-cor-de-chasse',
#   'WebsiteUrl': 'https://www.lecordechasse.be/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': "'t Overhamme",
#   'Year': 2021,
#   'Address': 'Brusselsesteenweg 163, Aalst, 9300, Belgium',
#   'City': 'Aalst',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 55.0,
#   'MaxPrice': 95.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern Cuisine',
#   'Longitude': 4.0662034,
#   'Latitude': 50.928478,
#   'PhoneNumber': 3253778599.0,
#   'Url': 'https://guide.michelin.com/en/oost-vlaanderen/aalst/restaurant/t-overhamme',
#   'WebsiteUrl': 'https://www.toverhamme.be/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'Michel',
#   'Year': 2021,
#   'Address': 'Gossetlaan 31, Groot-Bijgaarden, 1702, Belgium',
#   'City': 'Groot-Bijgaarden',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 55.0,
#   'MaxPrice': 140.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern French',
#   'Longitude': 4.2674168,
#   'Latitude': 50.8716705,
#   'PhoneNumber': 3224666591.0,
#   'Url': 'https://guide.michelin.com/en/vlaams-brabant/groot-bijgaarden/restaurant/michel209484',
#   'WebsiteUrl': 'https://www.restaurant-michel.be/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'Attablez-vous',
#   'Year': 2021,
#   'Address': 'Tienne Maquet 16, Namur, 5000, Belgium',
#   'City': 'Namur',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 42.0,
#   'MaxPrice': 105.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Creative French, Modern French',
#   'Longitude': 4.8540444,
#   'Latitude': 50.444706,
#   'PhoneNumber': 3281201023.0,
#   'Url': 'https://guide.michelin.com/en/namur/namur/restaurant/attablez-vous',
#   'WebsiteUrl': 'https://www.attablezvous.be/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'Eyckerhof',
#   'Year': 2021,
#   'Address': 'Spuistraat 21, Bornem, 2880, Belgium',
#   'City': 'Bornem',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 49.0,
#   'MaxPrice': 110.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern French',
#   'Longitude': 4.2897743,
#   'Latitude': 51.0848511,
#   'PhoneNumber': 3238890718.0,
#   'Url': 'https://guide.michelin.com/en/antwerpen/bornem/restaurant/eyckerhof',
#   'WebsiteUrl': 'https://www.eyckerhof.be/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': "'t Truffeltje",
#   'Year': 2021,
#   'Address': 'Bogaerdstraat 20, Dendermonde, 9200, Belgium',
#   'City': 'Dendermonde',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 45.0,
#   'MaxPrice': 100.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern French, Modern Cuisine',
#   'Longitude': 4.1026273,
#   'Latitude': 51.0310014,
#   'PhoneNumber': 3252224590.0,
#   'Url': 'https://guide.michelin.com/en/oost-vlaanderen/dendermonde/restaurant/t-truffeltje',
#   'WebsiteUrl': 'https://www.truffeltje.be/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'Kommilfoo',
#   'Year': 2021,
#   'Address': 'Vlaamse Kaai 17, Antwerpen, 2000, Belgium',
#   'City': 'Antwerpen',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 45.0,
#   'MaxPrice': 120.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Creative',
#   'Longitude': 4.392667,
#   'Latitude': 51.2111875,
#   'PhoneNumber': 3232373000.0,
#   'Url': 'https://guide.michelin.com/en/antwerpen/be-antwerpen/restaurant/kommilfoo',
#   'WebsiteUrl': 'https://www.restaurantkommilfoo.be/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'Zur Post',
#   'Year': 2021,
#   'Address': 'Hauptstraße 39, Saint Vith, 4780, Belgium',
#   'City': 'Saint Vith',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 65.0,
#   'MaxPrice': 129.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern Cuisine',
#   'Longitude': 6.12611,
#   'Latitude': 50.28043,
#   'PhoneNumber': 3280228027.0,
#   'Url': 'https://guide.michelin.com/en/liege/sankt-vith/restaurant/zur-post210392',
#   'WebsiteUrl': 'https://www.hotelzurpost.be/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'De Pastorie',
#   'Year': 2021,
#   'Address': 'Plaats 2, Lichtaart, 2460, Belgium',
#   'City': 'Lichtaart',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 50.0,
#   'MaxPrice': 130.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern Cuisine',
#   'Longitude': 4.9241458,
#   'Latitude': 51.2260206,
#   'PhoneNumber': 3214557786.0,
#   'Url': 'https://guide.michelin.com/en/antwerpen/lichtaart/restaurant/de-pastorie209876',
#   'WebsiteUrl': 'https://www.restaurantdepastorie.be/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'Sans Cravate',
#   'Year': 2021,
#   'Address': 'Langestraat 159, Brugge, 8000, Belgium',
#   'City': 'Brugge',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 49.0,
#   'MaxPrice': 129.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Creative French, Creative',
#   'Longitude': 3.2381662,
#   'Latitude': 51.2123748,
#   'PhoneNumber': 3250678310.0,
#   'Url': 'https://guide.michelin.com/en/west-vlaanderen/brugge/restaurant/sans-cravate',
#   'WebsiteUrl': 'https://www.sanscravate.be/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'OAK',
#   'Year': 2021,
#   'Address': 'Hoogstraat 167/001, Gent, 9000, Belgium',
#   'City': 'Gent',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 99.0,
#   'MaxPrice': 129.0,
#   'Currency': 'EUR',
#   'Cuisine': 'World Cuisine, Creative French',
#   'Longitude': 3.7109243,
#   'Latitude': 51.0560613,
#   'PhoneNumber': 3293539050.0,
#   'Url': 'https://guide.michelin.com/en/oost-vlaanderen/gent/restaurant/oak',
#   'WebsiteUrl': 'https://www.oakgent.be/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'Le Pilori',
#   'Year': 2021,
#   'Address': 'rue du Pilori 10, Écaussinnes-Lalaing, 7191, Belgium',
#   'City': 'Écaussinnes-Lalaing',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 39.0,
#   'MaxPrice': 95.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern French',
#   'Longitude': 4.1795447,
#   'Latitude': 50.5701335,
#   'PhoneNumber': 3267442318.0,
#   'Url': 'https://guide.michelin.com/en/hainaut/caussinnes-lalaing/restaurant/le-pilori',
#   'WebsiteUrl': 'https://www.pilori.be/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'La Belle',
#   'Year': 2021,
#   'Address': 'Bel 162, Geel, 2440, Belgium',
#   'City': 'Geel',
#   'Country': 'Belgium',
#   'Continent': 'Europe',
#   'MinPrice': 58.0,
#   'MaxPrice': 145.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Creative French',
#   'Longitude': 5.0637505,
#   'Latitude': 51.1630964,
#   'PhoneNumber': 3214708451.0,
#   'Url': 'https://guide.michelin.com/en/antwerpen/geel/restaurant/la-belle',
# ...
#   'PhoneNumber': 33145447373.0,
#   'Url': 'https://guide.michelin.com/en/ile-de-france/paris/restaurant/gaya-par-pierre-gagnaire',
#   'WebsiteUrl': 'https://pierregagnaire.com/restaurants/gaya',
#   'Award': '1 MICHELIN Star'},
#  {'Name': "L'Atelier de Joël Robuchon - St-Germain",
#   'Year': 2021,
#   'Address': '5 rue de Montalembert, Paris, 75007, France',
#   'City': 'Paris',
#   'Country': 'France',
#   'Continent': 'Europe',
#   'MinPrice': 160.0,
#   'MaxPrice': 175.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Creative, Modern Cuisine',
#   'Longitude': 2.3278568,
#   'Latitude': 48.85681,
#   'PhoneNumber': 33142225656.0,
#   'Url': 'https://guide.michelin.com/en/ile-de-france/paris/restaurant/l-atelier-de-joel-robuchon-st-germain',
#   'WebsiteUrl': 'https://www.joel-robuchon.com/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'Pilgrim',
#   'Year': 2021,
#   'Address': '8 rue Nicolas-Charlet, Paris, 75015, France',
#   'City': 'Paris',
#   'Country': 'France',
#   'Continent': 'Europe',
#   'MinPrice': 45.0,
#   'MaxPrice': 150.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern Cuisine',
#   'Longitude': 2.313917,
#   'Latitude': 48.8425254,
#   'PhoneNumber': 33140290971.0,
#   'Url': 'https://guide.michelin.com/en/ile-de-france/paris/restaurant/pilgrim1000208',
#   'WebsiteUrl': 'https://www.pilgrimparis.com/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'Azimut',
#   'Year': 2021,
#   'Address': "273 rue de la Madelon,  Immeuble l'Or Blanc, centre station 1300, Le Praz, Courchevel, 73120, France",
#   'City': 'Courchevel',
#   'Country': 'France',
#   'Continent': 'Europe',
#   'MinPrice': 45.0,
#   'MaxPrice': 108.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern Cuisine, Traditional Cuisine',
#   'Longitude': 6.62345,
#   'Latitude': 45.43329,
#   'PhoneNumber': 33479062590.0,
#   'Url': 'https://guide.michelin.com/en/auvergne-rhone-alpes/courchevel/restaurant/azimut',
#   'WebsiteUrl': 'https://www.restaurantazimut.com/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'La Table de la Bergerie',
#   'Year': 2021,
#   'Address': 'La Bergerie, Le Champ-sur-Layon, 49380, France',
#   'City': 'Le Champ-sur-Layon',
#   'Country': 'France',
#   'Continent': 'Europe',
#   'MinPrice': 30.0,
#   'MaxPrice': 80.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern Cuisine',
#   'Longitude': -0.59238,
#   'Latitude': 47.26803,
#   'PhoneNumber': 33241783062.0,
#   'Url': 'https://guide.michelin.com/en/pays-de-la-loire/le-champ-sur-layon/restaurant/la-table-de-la-bergerie',
#   'WebsiteUrl': 'http://www.latable-bergerie.fr/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'Julien Binz',
#   'Year': 2021,
#   'Address': '7 rue des Cigognes, Ammerschwihr, 68770, France',
#   'City': 'Ammerschwihr',
#   'Country': 'France',
#   'Continent': 'Europe',
#   'MinPrice': 72.0,
#   'MaxPrice': 105.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern Cuisine',
#   'Longitude': 7.2828891,
#   'Latitude': 48.125491,
#   'PhoneNumber': 33389229823.0,
#   'Url': 'https://guide.michelin.com/en/grand-est/ammerschwihr/restaurant/julien-binz',
#   'WebsiteUrl': 'https://www.restaurantjulienbinz.com/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'Le Royal',
#   'Year': 2021,
#   'Address': 'Hameau de Bellevue, 9 rue de la République, Champillon, 51160, France',
#   'City': 'Champillon',
#   'Country': 'France',
#   'Continent': 'Europe',
#   'MinPrice': 140.0,
#   'MaxPrice': 280.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern Cuisine',
#   'Longitude': 3.9767776,
#   'Latitude': 49.0912374,
#   'PhoneNumber': 33326528711.0,
#   'Url': 'https://guide.michelin.com/en/grand-est/champillon/restaurant/le-royal',
#   'WebsiteUrl': 'https://www.royalchampagne.com/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'Agapé',
#   'Year': 2021,
#   'Address': "51 rue Jouffroy-D'Abbans, Paris, 75017, France",
#   'City': 'Paris',
#   'Country': 'France',
#   'Continent': 'Europe',
#   'MinPrice': 54.0,
#   'MaxPrice': 195.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern Cuisine',
#   'Longitude': 2.3070328,
#   'Latitude': 48.885054,
#   'PhoneNumber': 33142272018.0,
#   'Url': 'https://guide.michelin.com/en/ile-de-france/paris/restaurant/agape',
#   'WebsiteUrl': 'https://www.agape-paris.fr/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': "L'Émulsion",
#   'Year': 2021,
#   'Address': '57 route de Lyon, lieu-dit La Grive, Saint-Alban-de-Roche, 38080, France',
#   'City': 'Saint-Alban-de-Roche',
#   'Country': 'France',
#   'Continent': 'Europe',
#   'MinPrice': 65.0,
#   'MaxPrice': 90.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern Cuisine',
#   'Longitude': 5.2312885,
#   'Latitude': 45.598532,
#   'PhoneNumber': 33474281912.0,
#   'Url': 'https://guide.michelin.com/en/auvergne-rhone-alpes/saint-alban-de-roche/restaurant/l-emulsion327218',
#   'WebsiteUrl': 'https://www.lemulsion-restaurant.com/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'Le Saint-James',
#   'Year': 2021,
#   'Address': '3 place Camille-Hosteins, Bouliac, 33270, France',
#   'City': 'Bouliac',
#   'Country': 'France',
#   'Continent': 'Europe',
#   'MinPrice': 59.0,
#   'MaxPrice': 170.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern Cuisine',
#   'Longitude': -0.5038692,
#   'Latitude': 44.8142793,
#   'PhoneNumber': 33557970600.0,
#   'Url': 'https://guide.michelin.com/en/nouvelle-aquitaine/bouliac/restaurant/le-saint-james',
#   'WebsiteUrl': 'https://www.saintjames-bouliac.com/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'Miraflores',
#   'Year': 2021,
#   'Address': '112 boulevard des Belges, Lyon, 69006, France',
#   'City': 'Lyon',
#   'Country': 'France',
#   'Continent': 'Europe',
#   'MinPrice': 150.0,
#   'MaxPrice': 150.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Peruvian',
#   'Longitude': 4.8588247,
#   'Latitude': 45.7682684,
#   'PhoneNumber': 33478244971.0,
#   'Url': 'https://guide.michelin.com/en/auvergne-rhone-alpes/lyon/restaurant/miraflores-1190862',
#   'WebsiteUrl': 'https://www.restaurant-miraflores.com/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'Skab',
#   'Year': 2021,
#   'Address': '7 rue de la République, Nîmes, 30000, France',
#   'City': 'Nîmes',
#   'Country': 'France',
#   'Continent': 'Europe',
#   'MinPrice': 50.0,
#   'MaxPrice': 148.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern Cuisine',
#   'Longitude': 4.35921,
#   'Latitude': 43.833187,
#   'PhoneNumber': 33466219430.0,
#   'Url': 'https://guide.michelin.com/en/occitanie/nimes/restaurant/skab',
#   'WebsiteUrl': 'https://www.restaurant-skab.fr/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'Ithurria',
#   'Year': 2021,
#   'Address': 'Place du Fronton, Ainhoa, 64250, France',
#   'City': 'Ainhoa',
#   'Country': 'France',
#   'Continent': 'Europe',
#   'MinPrice': 49.0,
#   'MaxPrice': 94.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern Cuisine, Classic Cuisine',
#   'Longitude': -1.49912,
#   'Latitude': 43.30768,
#   'PhoneNumber': 33559299211.0,
#   'Url': 'https://guide.michelin.com/en/nouvelle-aquitaine/ainhoa/restaurant/ithurria',
#   'WebsiteUrl': 'https://www.ithurria.com/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'Auberge St-Laurent',
#   'Year': 2021,
#   'Address': '1 rue de la Fontaine, Sierentz, 68510, France',
#   'City': 'Sierentz',
#   'Country': 'France',
#   'Continent': 'Europe',
#   'MinPrice': 35.0,
#   'MaxPrice': 95.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern Cuisine, Traditional Cuisine',
#   'Longitude': 7.4539991,
#   'Latitude': 47.6540637,
#   'PhoneNumber': 33389815281.0,
#   'Url': 'https://guide.michelin.com/en/grand-est/sierentz/restaurant/auberge-st-laurent',
#   'WebsiteUrl': 'https://www.auberge-saintlaurent.fr/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': "L'Archeste",
#   'Year': 2021,
#   'Address': '79 rue de la Tour, Paris, 75016, France',
#   'City': 'Paris',
#   'Country': 'France',
#   'Continent': 'Europe',
#   'MinPrice': 60.0,
#   'MaxPrice': 190.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Creative',
#   'Longitude': 2.2782878,
#   'Latitude': 48.8617373,
#   'PhoneNumber': 33140716968.0,
#   'Url': 'https://guide.michelin.com/en/ile-de-france/paris/restaurant/l-archeste',
#   'WebsiteUrl': 'https://www.archeste.fr/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'Signature',
#   'Year': 2021,
#   'Address': '180 rue du Rouet, Marseille, 13008, France',
#   'City': 'Marseille',
#   'Country': 'France',
#   'Continent': 'Europe',
#   'MinPrice': 32.0,
#   'MaxPrice': 110.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern Cuisine',
#   'Longitude': 5.3944545,
#   'Latitude': 43.2764287,
#   'PhoneNumber': 33465855348.0,
#   'Url': 'https://guide.michelin.com/en/provence-alpes-cote-dazur/marseille/restaurant/signature1186475',
#   'WebsiteUrl': 'https://www.signaturemarseille.com/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': '114, Faubourg',
#   'Year': 2021,
#   'Address': 'Le Bristol, 114 rue du Faubourg-Saint-Honoré, Paris, 75008, France',
#   'City': 'Paris',
#   'Country': 'France',
#   'Continent': 'Europe',
#   'MinPrice': 130.0,
#   'MaxPrice': 150.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern Cuisine',
#   'Longitude': 2.3142125,
#   'Latitude': 48.8717748,
#   'PhoneNumber': 33153434444.0,
#   'Url': 'https://guide.michelin.com/en/ile-de-france/paris/restaurant/114-faubourg',
#   'WebsiteUrl': 'https://www.lebristolparis.com/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': "Auberge de l'Abbaye",
#   'Year': 2021,
#   'Address': 'Place des Anciens-Combattants, Ambronay, 01500, France',
#   'City': 'Ambronay',
#   'Country': 'France',
#   'Continent': 'Europe',
#   'MinPrice': 70.0,
#   'MaxPrice': 105.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern Cuisine',
#   'Longitude': 5.3606423,
#   'Latitude': 46.0073829,
#   'PhoneNumber': 33474464254.0,
#   'Url': 'https://guide.michelin.com/en/auvergne-rhone-alpes/ambronay/restaurant/auberge-de-l-abbaye65232',
#   'WebsiteUrl': 'https://www.aubergedelabbaye-ambronay.com/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'Le Vivier',
#   'Year': 2021,
#   'Address': "800 cours Fernande-Peyre, L'Isle-sur-la-Sorgue, 84800, France",
#   'City': "L'Isle-sur-la-Sorgue",
#   'Country': 'France',
#   'Continent': 'Europe',
#   'MinPrice': 36.0,
#   'MaxPrice': 120.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern Cuisine',
#   'Longitude': 5.0633622,
#   'Latitude': 43.9257707,
#   'PhoneNumber': 33490385280.0,
#   'Url': 'https://guide.michelin.com/en/provence-alpes-cote-dazur/l-isle-sur-la-sorgue/restaurant/le-vivier3857',
#   'WebsiteUrl': 'https://www.levivier-restaurant.com/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'La Table de Nans',
#   'Year': 2021,
#   'Address': '126 corniche du Liouquet, La Ciotat, 13600, France',
#   'City': 'La Ciotat',
#   'Country': 'France',
#   'Continent': 'Europe',
#   'MinPrice': 85.0,
#   'MaxPrice': 120.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Mediterranean Cuisine',
#   'Longitude': 5.6666678,
#   'Latitude': 43.1828371,
#   'PhoneNumber': 33442831106.0,
#   'Url': 'https://guide.michelin.com/en/provence-alpes-cote-dazur/la-ciotat/restaurant/la-table-de-nans',
#   'WebsiteUrl': 'https://www.latabledenans.com/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': "L'Oiseau Blanc",
#   'Year': 2021,
#   'Address': '19 avenue Kléber, Paris, 75116, France',
#   'City': 'Paris',
#   'Country': 'France',
#   'Continent': 'Europe',
#   'MinPrice': 95.0,
#   'MaxPrice': 225.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern Cuisine',
#   'Longitude': 2.29328,
#   'Latitude': 48.87099,
#   'PhoneNumber': 33158126730.0,
#   'Url': 'https://guide.michelin.com/en/ile-de-france/paris/restaurant/l-oiseau-blanc',
#   'WebsiteUrl': 'https://www.peninsula.com/fr/paris/hotel-fine-dining/french-rooftop-loiseau-blanc',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'Le Hittau',
#   'Year': 2021,
#   'Address': '1 rue du Nouaou, Saint-Vincent-de-Tyrosse, 40230, France',
#   'City': 'Saint-Vincent-de-Tyrosse',
#   'Country': 'France',
#   'Continent': 'Europe',
#   'MinPrice': 36.0,
#   'MaxPrice': 92.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern Cuisine',
#   'Longitude': -1.2963393,
#   'Latitude': 43.6616803,
#   'PhoneNumber': 33558771185.0,
#   'Url': 'https://guide.michelin.com/en/nouvelle-aquitaine/saint-vincent-de-tyrosse/restaurant/le-hittau',
#   'WebsiteUrl': 'http://www.lehittau.fr/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'La Tour des Vents',
#   'Year': 2021,
#   'Address': 'Lieu-dit Moulin-de-Malfourat, Monbazillac, 24240, France',
#   'City': 'Monbazillac',
#   'Country': 'France',
#   'Continent': 'Europe',
#   'MinPrice': 54.0,
#   'MaxPrice': 97.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern Cuisine',
#   'Longitude': 0.4609734,
#   'Latitude': 44.7969051,
#   'PhoneNumber': 33553583010.0,
#   'Url': 'https://guide.michelin.com/en/nouvelle-aquitaine/monbazillac/restaurant/la-tour-des-vents',
#   'WebsiteUrl': 'https://www.tourdesvents.com/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'Le Prieuré',
#   'Year': 2021,
#   'Address': '11 rue de la Mairie, Ambierle, 42820, France',
#   'City': 'Ambierle',
#   'Country': 'France',
#   'Continent': 'Europe',
#   'MinPrice': 49.0,
#   'MaxPrice': 99.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern Cuisine',
#   'Longitude': 3.8962151,
#   'Latitude': 46.1040493,
#   'PhoneNumber': 33477656324.0,
#   'Url': 'https://guide.michelin.com/en/auvergne-rhone-alpes/ambierle/restaurant/le-prieure189',
#   'WebsiteUrl': 'https://www.leprieureambierle.fr/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': "La Table d'Hôtes - Le Quatrième Mur",
#   'Year': 2021,
#   'Address': '2 place de la Comédie, Bordeaux, 33000, France',
#   'City': 'Bordeaux',
#   'Country': 'France',
#   'Continent': 'Europe',
#   'MinPrice': 170.0,
#   'MaxPrice': 170.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Creative',
#   'Longitude': -0.57423,
#   'Latitude': 44.84258,
#   'PhoneNumber': 33556024970.0,
#   'Url': 'https://guide.michelin.com/en/nouvelle-aquitaine/bordeaux/restaurant/la-table-d-hotes-le-quatrieme-mur',
#   'WebsiteUrl': 'https://www.quatrieme-mur.com/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': "La Table d'Olivier",
#   'Year': 2021,
#   'Address': '3 rue Saint-Ambroise, Brive-la-Gaillarde, 19100, France',
#   'City': 'Brive-la-Gaillarde',
#   'Country': 'France',
#   'Continent': 'Europe',
#   'MinPrice': 51.0,
#   'MaxPrice': 93.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern Cuisine',
#   'Longitude': 1.5308409,
#   'Latitude': 45.158952,
#   'PhoneNumber': 33555189595.0,
#   'Url': 'https://guide.michelin.com/en/nouvelle-aquitaine/brive-la-gaillarde/restaurant/la-table-d-olivier',
#   'WebsiteUrl': nan,
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'Pantagruel',
#   'Year': 2021,
#   'Address': '24 rue du Sentier, Paris, 75002, France',
#   'City': 'Paris',
#   'Country': 'France',
#   'Continent': 'Europe',
#   'MinPrice': 45.0,
#   'MaxPrice': 85.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern Cuisine',
#   'Longitude': 2.3464362,
#   'Latitude': 48.8700016,
#   'PhoneNumber': 33173747728.0,
#   'Url': 'https://guide.michelin.com/en/ile-de-france/paris/restaurant/pantagruel',
#   'WebsiteUrl': 'https://www.restaurant-pantagruel.com/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'Ed.Em',
#   'Year': 2021,
#   'Address': '4 impasse Chenevottes, Chassagne-Montrachet, 21190, France',
#   'City': 'Chassagne-Montrachet',
#   'Country': 'France',
#   'Continent': 'Europe',
#   'MinPrice': 40.0,
#   'MaxPrice': 90.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern Cuisine',
#   'Longitude': 4.7307466,
#   'Latitude': 46.9384965,
#   'PhoneNumber': 33380219494.0,
#   'Url': 'https://guide.michelin.com/en/bourgogne-franche-comte/chassagne-montrachet/restaurant/ed-em',
#   'WebsiteUrl': 'https://www.restaurant-edem.com/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'Ochre',
#   'Year': 2021,
#   'Address': '56 rue du Gué, Rueil-Malmaison, 92500, France',
#   'City': 'Rueil-Malmaison',
#   'Country': 'France',
#   'Continent': 'Europe',
#   'MinPrice': 55.0,
#   'MaxPrice': 115.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Modern Cuisine',
#   'Longitude': 2.1830535,
#   'Latitude': 48.8778387,
#   'PhoneNumber': 33981208169.0,
#   'Url': 'https://guide.michelin.com/en/ile-de-france/rueil-malmaison/restaurant/ochre',
#   'WebsiteUrl': 'https://www.ochre.fr/',
#   'Award': '1 MICHELIN Star'},
#  {'Name': 'La Table de Patrick Raingeard',
#   'Year': 2021,
#   'Address': '1312 avenue Raymond-Poincaré, Èze-Bord-de-Mer, 06360, France',
#   'City': 'Èze-Bord-de-Mer',
#   'Country': 'France',
#   'Continent': 'Europe',
#   'MinPrice': 130.0,
#   'MaxPrice': 190.0,
#   'Currency': 'EUR',
#   'Cuisine': 'Creative',
#   'Longitude': 7.3729219,
#   'Latitude': 43.7185999,
#   'PhoneNumber': 33493762929.0,
#   'Url': 'https://guide.michelin.com/en/provence-alpes-cote-dazur/ze-bord-de-mer/restaurant/la-table-de-patrick-raingeard',
#   'WebsiteUrl': 'https://www.capestel.com/',
#   'Award': '1 MICHELIN Star'},
#  ...]

# %%
# Define the database in Mongo
db = client["michelin"]

# %%
print(db)
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'michelin')

# %%
# Define the collection and insert data
db.restaurants.insert_many(data)
