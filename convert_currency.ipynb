# %%
import pandas as pd
from currency_converter import CurrencyConverter

c = CurrencyConverter()

# %%
michelin = 'data/2021CountryContinent.csv'

# %%
michelin_df = pd.read_csv(michelin, encoding='ISO-8859-1')

# %%
michelin_df.head()
# Out:
#             ï»¿Name  Year                                            Address  \
# 0      Les Eleveurs  2021                Suikerkaai 1a, Halle, 1500, Belgium
# 1             Ibaya  2021        Carretera General 2, Soldeu, AD100, Andorra
# 2  Celler d'en Toni  2021  Verge del Pilar 4, Andorra la Vella, AD500, An...
# 3            Amador  2021       Grinzinger StraÃe 86, Vienna, 1190, Austria
# 4  SENNS.Restaurant  2021     SÃ¶llheimerstrasse 16, Salzburg, 5020, Austria
#
#                City   Country Continent MinPrice MaxPrice Currency  \
# 0             Halle  Alemania    Europe       45      145      EUR
# 1            Soldeu   Andorra    Europe      110      145      EUR
# 2  Andorra la Vella   Andorra    Europe       72       72      EUR
# 3            Vienna   Austria    Europe      265      265      EUR
# 4          Salzburg   Austria    Europe       85      205      EUR
#
#                              Cuisine  Longitude   Latitude   PhoneNumber  \
# 0  Classic Cuisine, Regional Cuisine   4.237608  50.732199  3.223611e+09
# 1           Creative, Modern Cuisine   1.670949  42.575577  3.768707e+08
# 2                       Contemporary   1.531772  42.507145  3.768628e+08
# 3             Creative, Contemporary  16.358600  48.254011  4.370000e+11
# 4                           Creative  13.063449  47.836072  4.370000e+11
#
#                                                  Url  \
# 0  https://guide.michelin.com/en/vlaams-brabant/b...
# 1  https://guide.michelin.com/en/canillo/soldeu/r...
# 2  https://guide.michelin.com/en/andorra-la-vella...
# 3  https://guide.michelin.com/en/vienna/wien/rest...
# 4  https://guide.michelin.com/en/salzburg-region/...
#
#                           WebsiteUrl             Award
# 0       https://www.les-eleveurs.be/      Bib Gourmand
# 1          http://www.sporthotels.ad   1 MICHELIN Star
# 2       http://www.cellerdentoni.com      Bib Gourmand
# 3  http://www.restaurant-amador.com/  3 MICHELIN Stars
# 4      https://www.senns.restaurant/  2 MICHELIN Stars

# %%
def currency_convertor(michelin_df,new_currency='USD'):
    try:
        price = michelin_df['MaxPrice']
        curr = michelin_df['Currency']
        new_curr = c.convert(price,curr,new_currency)
        return new_curr
    except:
        print(f'{curr} failed')

michelin_df['max_usd'] = michelin_df.apply(lambda x: currency_convertor(x,new_currency='USD'), axis=1)
# Out:
# nan failed

# %%
michelin_df.head()
# Out:
#               Name    Year                                            Address  \
# 0           D.O.M.  2021.0  Rua BarÃ£o de Capanema 549, SÃ£o Paulo, 01411-...
# 1  Ryo Gastronomia  2021.0  Rua Pedroso Alvarenga 665, SÃ£o Paulo, 04531-0...
# 2           Oteque  2021.0  Rua Conde de IrajÃ¡ 581, Rio de Janeiro, 22271...
# 3              Oro  2021.0  Avenida General San Martin 889, Rio de Janeiro...
# 4        Kinoshita  2021.0  Rua Jacques FÃ©lix 405, SÃ£o Paulo, 04509-900,...
#
#          Location Region Continent MinPrice  MaxPrice Currency  \
# 0      SÃ£o Paulo    NaN       NaN      415     700.0      BRL
# 1      SÃ£o Paulo    NaN       NaN      160     650.0      BRL
# 2  Rio de Janeiro    NaN       NaN      440     440.0      BRL
# 3  Rio de Janeiro    NaN       NaN      445     555.0      BRL
# 4      SÃ£o Paulo    NaN       NaN       83     383.0      BRL
#
#           Cuisine  Longitude   Latitude   PhoneNumber  \
# 0        Creative -46.667479 -23.566181  5.510000e+11
# 1        Japanese -46.676905 -23.581449  5.510000e+11
# 2  Modern Cuisine -43.194424 -22.957470  5.520000e+11
# 3        Creative -43.224710 -22.986010  5.520000e+11
# 4        Japanese -46.671258 -23.591808  5.510000e+11
#
#                                                  Url  \
# 0  https://guide.michelin.com/en/sao-paulo-region...
# 1  https://guide.michelin.com/en/sao-paulo-region...
# 2  https://guide.michelin.com/en/rio-de-janeiro-r...
# 3  https://guide.michelin.com/en/rio-de-janeiro-r...
# 4  https://guide.michelin.com/en/sao-paulo-region...
#
#                                  WebsiteUrl             Award     max_usd
# 0         http://www.domrestaurante.com.br/  2 MICHELIN Stars  139.677179
# 1        https://www.ryogastronomia.com.br/  2 MICHELIN Stars  129.700238
# 2                   https://www.oteque.com/  2 MICHELIN Stars   87.797084
# 3         http://www.ororestaurante.com.br/  2 MICHELIN Stars  110.744049
# 4  https://www.restaurantekinoshita.com.br/   1 MICHELIN Star   76.423371

# %%
michelin_df.describe()
# Out:
#          Year       MaxPrice    Longitude     Latitude   PhoneNumber  \
# count  6375.0    6376.000000  6376.000000  6376.000000  6.268000e+03
# mean   2021.0    3806.529172    25.357138    41.260683  3.035166e+11
# std       0.0   18276.349027    64.651813    11.818583  1.521174e+12
# min    2021.0       2.000000  -123.719444   -23.638434  4.977184e+07
# 25%    2021.0      60.000000     0.649647    35.726995  3.314261e+10
# 50%    2021.0     120.000000     7.269377    43.761822  3.531653e+10
# 75%    2021.0     265.000000    19.052145    48.847792  8.522579e+10
# max    2021.0  380000.000000   139.847604    64.144365  4.980000e+13
#
#            max_usd
# count  6376.000000
# mean    117.049459
# std      88.678572
# min       0.601500
# 25%      53.851000
# 50%      91.616053
# 75%     157.827467
# max    1402.770525

# %%
bins = [0, 300, 600, 900, 1000, 1500]
labels = [1,2,3,4,5]
michelin_df['price'] = pd.cut(michelin_df['max_usd'], bins=bins, labels=labels)
michelin_df.head()
# Out:
#               Name    Year                                            Address  \
# 0           D.O.M.  2021.0  Rua BarÃ£o de Capanema 549, SÃ£o Paulo, 01411-...
# 1  Ryo Gastronomia  2021.0  Rua Pedroso Alvarenga 665, SÃ£o Paulo, 04531-0...
# 2           Oteque  2021.0  Rua Conde de IrajÃ¡ 581, Rio de Janeiro, 22271...
# 3              Oro  2021.0  Avenida General San Martin 889, Rio de Janeiro...
# 4        Kinoshita  2021.0  Rua Jacques FÃ©lix 405, SÃ£o Paulo, 04509-900,...
#
#          Location Region Continent MinPrice  MaxPrice Currency  \
# 0      SÃ£o Paulo    NaN       NaN      415     700.0      BRL
# 1      SÃ£o Paulo    NaN       NaN      160     650.0      BRL
# 2  Rio de Janeiro    NaN       NaN      440     440.0      BRL
# 3  Rio de Janeiro    NaN       NaN      445     555.0      BRL
# 4      SÃ£o Paulo    NaN       NaN       83     383.0      BRL
#
#           Cuisine  Longitude   Latitude   PhoneNumber  \
# 0        Creative -46.667479 -23.566181  5.510000e+11
# 1        Japanese -46.676905 -23.581449  5.510000e+11
# 2  Modern Cuisine -43.194424 -22.957470  5.520000e+11
# 3        Creative -43.224710 -22.986010  5.520000e+11
# 4        Japanese -46.671258 -23.591808  5.510000e+11
#
#                                                  Url  \
# 0  https://guide.michelin.com/en/sao-paulo-region...
# 1  https://guide.michelin.com/en/sao-paulo-region...
# 2  https://guide.michelin.com/en/rio-de-janeiro-r...
# 3  https://guide.michelin.com/en/rio-de-janeiro-r...
# 4  https://guide.michelin.com/en/sao-paulo-region...
#
#                                  WebsiteUrl             Award     max_usd  \
# 0         http://www.domrestaurante.com.br/  2 MICHELIN Stars  139.677179
# 1        https://www.ryogastronomia.com.br/  2 MICHELIN Stars  129.700238
# 2                   https://www.oteque.com/  2 MICHELIN Stars   87.797084
# 3         http://www.ororestaurante.com.br/  2 MICHELIN Stars  110.744049
# 4  https://www.restaurantekinoshita.com.br/   1 MICHELIN Star   76.423371
#
#   price
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1

# %%
# Out:
#          Year       MaxPrice    Longitude     Latitude   PhoneNumber  \
# count  6375.0    6376.000000  6376.000000  6376.000000  6.268000e+03
# mean   2021.0    3806.529172    25.357138    41.260683  3.035166e+11
# std       0.0   18276.349027    64.651813    11.818583  1.521174e+12
# min    2021.0       2.000000  -123.719444   -23.638434  4.977184e+07
# 25%    2021.0      60.000000     0.649647    35.726995  3.314261e+10
# 50%    2021.0     120.000000     7.269377    43.761822  3.531653e+10
# 75%    2021.0     265.000000    19.052145    48.847792  8.522579e+10
# max    2021.0  380000.000000   139.847604    64.144365  4.980000e+13
#
#            max_usd
# count  6376.000000
# mean    117.049459
# std      88.678572
# min       0.601500
# 25%      53.851000
# 50%      91.616053
# 75%     157.827467
# max    1402.770525
